# %% [markdown]
# # EDA

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
df0 = pd.read_csv(r"ready_data/data_a0_encoded.csv")
df1 = pd.read_csv(r"ready_data/data_a1_encoded.csv")

# %%
df0.head()
# Out:
#    Time  Target  HomeTeam_enc  avg_goals_in_last5_home  \
# 0    19       1           420                      NaN
# 1    19       0           101                      NaN
# 2    19       1             8                      NaN
# 3    19       1           201                      NaN
# 4    19       0           372                      NaN
#
#    avg_goals_conceded_last5_home  AwayTeam_enc  avg_goals_in_last5_away  \
# 0                            NaN           204                      NaN
# 1                            NaN           444                      NaN
# 2                            NaN           245                      NaN
# 3                            NaN           196                      NaN
# 4                            NaN            44                      NaN
#
#    avg_goals_conceded_last5_away  Year  Month  ...  Country_G  Country_I  \
# 0                            NaN  2019      7  ...      False      False
# ...

# %%
df0.describe().T
# Out:
#                                  count         mean         std     min  \
# Time                           42593.0    16.264292    2.468946    10.0
# Target                         42593.0     0.499894    0.500006     0.0
# HomeTeam_enc                   42593.0   238.533069  137.843524     0.0
# avg_goals_in_last5_home        42115.0     1.468535    0.681854     0.0
# avg_goals_conceded_last5_home  42115.0     1.193677    0.574891     0.0
# AwayTeam_enc                   42593.0   238.612284  137.810745     0.0
# avg_goals_in_last5_away        42115.0     1.196533    0.597631     0.0
# avg_goals_conceded_last5_away  42115.0     1.464568    0.640763     0.0
# Year                           42593.0  2022.055619    1.763826  2019.0
# Month                          42593.0     6.442232    3.827781     1.0
# Dayofweek                      42593.0     4.412861    1.732260     0.0
# Is_weekend                     42593.0     0.719062    0.449463     0.0
# ...

# %%
df1.head()
# Out:
#    Time  Target  HomeTeam_enc  avg_goals_in_last5_home  \
# 0    19       0           307                      NaN
# 1    19       1           184                      NaN
# 2    19       0           372                      NaN
# 3    19       1           420                      NaN
# 4    19       1           201                      NaN
#
#    avg_goals_conceded_last5_home  AwayTeam_enc  avg_goals_in_last5_away  \
# 0                            NaN           435                      1.4
# 1                            NaN           238                      1.0
# 2                            NaN            44                      1.4
# 3                            NaN           204                      1.2
# 4                            NaN           196                      0.8
#
#    avg_goals_conceded_last5_away  market_decisiveness  expected_total_goals  \
# 0                            2.0             0.093350              1.677022
# ...
